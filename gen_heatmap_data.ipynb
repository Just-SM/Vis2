# %%
import pandas as pd
import nltk
from tqdm import tqdm

# %%
df = pd.read_csv("dblp-v10-titles_and_date-only.csv")
df = df.head(10000)

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\romaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\romaf\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
def token_and_filter_pos_combos(text_corpus):
      
    corpus = []
    for sent in tqdm(text_corpus):

        sent_tokens = []
        
        words = []
        for word,tag in nltk.pos_tag(nltk.word_tokenize(sent)):
            if tag in {"JJ","JJR","JJS","NN","NNS","NNP","NNPS"}:
                words.append(word)
            else:
                if len(words) > 0:
                    sent_tokens.append(" ".join(words))
                words = []
        if len(words) > 0:
                    sent_tokens.append(" ".join(words))
        corpus.append(sent_tokens)
    return(corpus)

# %%
terms = token_and_filter_pos_combos(df['title'].to_list())
# Out:
# 100%|██████████| 10000/10000 [00:06<00:00, 1496.49it/s]

# %%
import math
from collections import Counter

def compute_tf_icf(sentence_terms):
    # Flatten list of terms for TF computation
    flattened_terms = [term for sentence in sentence_terms for term in sentence]
    term_counts = Counter(flattened_terms)
    
    # Total number of terms
    total_terms = len(flattened_terms)
    
    # Compute TF for each term
    tf = {term: count / total_terms for term, count in term_counts.items()}
    
    # Compute ICF for each term
    total_sentences = len(sentence_terms)
    term_in_sentences = Counter(term for sentence in sentence_terms for term in set(sentence))
    icf = {term: math.log(total_sentences / (1 + count)) for term, count in term_in_sentences.items()}
    
    # Compute TF-ICF
    tf_icf = {term: tf[term] * icf[term] for term in tf.keys()}
    
    return tf_icf

# %%
tf_icf_scores = compute_tf_icf(terms)

# %%
from collections import Counter

yearly_terms = {year: [] for year in df['year'].unique()}

for terms, y in zip(terms,df['year']):
    for term in terms:
        if tf_icf_scores[term] > 0.001:
            yearly_terms[y].append(term)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
year_terms_scores = {year: [] for year in df['year'].unique()}

for year, terms in yearly_terms.items():
    scores = MinMaxScaler((0.1,1)).fit_transform(np.array(list(Counter(yearly_terms[2008]).values())).reshape(-1,1))
    year_terms_scores[year] = list(zip(terms,scores))

# %%
year_terms_scores
# Out:
# {2008: [('new approach', array([0.1])),
#   ('image segmentation', array([0.1])),
#   ('Application', array([0.9])),
#   ('Integration', array([0.2])),
#   ('Wireless Ad Hoc Networks', array([0.2])),
#   ('people', array([0.1])),
#   ('mobile robot', array([0.2])),
#   ('evolution', array([0.2])),
#   ('Research', array([0.9])),
#   ('IP', array([0.3])),
#   ('control', array([0.4])),
#   ('OFDM systems', array([0.1])),
#   ('Application', array([0.2])),
#   ('Research', array([0.2])),
#   ('tracking', array([0.1])),
#   ('Impact', array([0.3])),
#   ('performance', array([0.8])),
#   ('objects', array([0.1])),
#   ('Application', array([0.2])),
#   ('Analysis', array([0.3])),
#   ('effects', array([0.2])),
#   ('Number', array([0.1])),
#   ('H.264/AVC', array([0.5])),
#   ('Sensor Networks', array([0.3])),
#   ('Distributed', array([0.2])),
#   ('Design', array([0.1])),
#   ('Efficient', array([0.5])),
#   ('implications', array([0.2])),
#   ('power', array([0.1])),
#   ('Study', array([0.2])),
#   ('Integration', array([0.2])),
#   ('simulation', array([0.2])),
#   ('Application', array([0.4])),
#   ('extension', array([0.1])),
#   ('H.264/AVC', array([0.1])),
#   ('Ontology', array([0.1])),
#   ('Calibration', array([1.])),
#   ('machine learning', array([0.3])),
#   ('scheme', array([0.2])),
#   ('incomplete information', array([0.2])),
#   ('Reconstruction', array([0.2])),
#   ('Throughput', array([0.1])),
#   ('Wireless Sensor Networks', array([0.8])),
#   ('images', array([0.1])),
#   ('objects', array([0.2])),
#   ('Investigation', array([0.2])),
#   ('mobile robots', array([0.3])),
#   ('Evaluation', array([0.3])),
#   ('social networks', array([0.3])),
#   ('IP', array([0.5])),
#   ('Performance', array([0.1])),
#   ('Research', array([0.4])),
#   ('Fusion', array([0.1])),
#   ('RFID', array([0.1])),
#   ('mobile robot', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('VANETs', array([0.3])),
#   ('scheme', array([0.4])),
#   ('IEEE', array([0.1])),
#   ('networks', array([0.1])),
#   ('Towards', array([0.2])),
#   ('Implementation', array([0.4])),
#   ('Models', array([0.2])),
#   ('model', array([0.1])),
#   ('Performance', array([0.3])),
#   ('Measurement', array([0.2])),
#   ('analysis', array([0.2])),
#   ('Framework', array([0.1])),
#   ('evolution', array([0.1])),
#   ('Case Study', array([0.2])),
#   ('Wireless Sensor Networks', array([0.2])),
#   ('Implementation', array([0.1])),
#   ('Research', array([0.2])),
#   ('Implementation', array([0.2])),
#   ('Effects', array([0.1])),
#   ('Optimization', array([0.2])),
#   ('ontologies', array([0.1])),
#   ('knowledge', array([0.2])),
#   ('Classification', array([0.2])),
#   ('Control', array([0.1])),
#   ('design', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('Wikipedia', array([0.1])),
#   ('Detection', array([0.1])),
#   ('Characterization', array([0.1])),
#   ('scheme', array([0.1])),
#   ('Number', array([0.1])),
#   ('Study', array([0.1])),
#   ('Parallel', array([0.1])),
#   ('Wireless Sensor Networks', array([0.2])),
#   ('dynamic environments', array([0.2])),
#   ('Impact', array([0.1])),
#   ('Performance', array([0.1])),
#   ('Extension', array([0.3])),
#   ('Class', array([0.2])),
#   ('Systems', array([0.1])),
#   ('search', array([0.1])),
#   ('Validation', array([0.3])),
#   ('Evolution', array([0.1])),
#   ('Assessment', array([0.3])),
#   ('video', array([0.2])),
#   ('motion', array([0.2])),
#   ('technology', array([0.3])),
#   ('Part', array([0.4])),
#   ('sensor networks', array([0.1])),
#   ('Use', array([0.4])),
#   ('Influence', array([0.1])),
#   ('Requirements', array([0.1])),
#   ('Effects', array([0.2])),
#   ('Performance', array([0.1])),
#   ('graphs', array([0.1])),
#   ('Wireless Ad Hoc Networks', array([0.1])),
#   ('Comments', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Cognitive Radio Networks', array([0.4])),
#   ('Effect', array([0.2])),
#   ('Optimization', array([0.1])),
#   ('genetic algorithms', array([0.1])),
#   ('Learning', array([0.1])),
#   ('Computer', array([0.1])),
#   ('Research', array([0.1])),
#   ('measurement', array([0.2])),
#   ('segmentation', array([0.1])),
#   ('Construction', array([0.1])),
#   ('Application', array([0.1])),
#   ('normal', array([0.2])),
#   ('nonlinear systems', array([0.1])),
#   ('strategies', array([0.1])),
#   ('normal', array([0.2])),
#   ('Alzheimer', array([0.1])),
#   ('Calibration', array([0.1])),
#   ('mobile robots', array([0.2])),
#   ('Simulation', array([0.2])),
#   ('Implementation', array([0.1])),
#   ('system', array([0.2])),
#   ('method', array([0.1])),
#   ('model', array([0.1])),
#   ('review', array([0.1])),
#   ('Investigation', array([0.1])),
#   ('Network', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('implications', array([0.1])),
#   ('Applications', array([0.1])),
#   ('IEEE', array([0.1])),
#   ('Wireless Networks', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('design', array([0.1])),
#   ('VANETs', array([0.1])),
#   ('survey', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('Effects', array([0.1])),
#   ('Web', array([0.1])),
#   ('localization', array([0.1])),
#   ('learning', array([0.1])),
#   ('Comparative Study', array([0.2])),
#   ('method', array([0.1])),
#   ('machine learning', array([0.1])),
#   ('Design', array([0.1])),
#   ('Experiment', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Performance', array([0.1])),
#   ('Network', array([0.2])),
#   ('Objects', array([0.2])),
#   ('Sensor Networks', array([0.1])),
#   ('Simulation', array([0.1])),
#   ('Development', array([0.1])),
#   ('synthesis', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('Algorithm', array([0.1])),
#   ('Information', array([0.1])),
#   ('approach', array([0.1])),
#   ('Overview', array([0.1])),
#   ('Research', array([0.1])),
#   ('Wireless Networks', array([0.2])),
#   ('measurement', array([0.3])),
#   ('Performance', array([0.2])),
#   ('trust', array([0.1])),
#   ('method', array([0.1])),
#   ('Estimation', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Generation', array([0.1])),
#   ('Review', array([0.1])),
#   ('role', array([0.1])),
#   ('review', array([0.1])),
#   ('Verification', array([0.1])),
#   ('Benefits', array([0.1])),
#   ('applications', array([0.1])),
#   ('H.264/AVC', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('People', array([0.1])),
#   ('Performance Evaluation', array([0.1])),
#   ('Presence', array([0.1])),
#   ('Theory', array([0.1])),
#   ('Practice', array([0.1])),
#   ('XML', array([0.1])),
#   ('solution', array([0.1])),
#   ('Approach', array([0.1])),
#   ('solution', array([0.1])),
#   ('Application', array([0.1])),
#   ('optimization', array([0.1])),
#   ('scheme', array([0.1])),
#   ('Applications', array([0.1])),
#   ('estimation', array([0.1])),
#   ('complexity', array([0.1])),
#   ('learning', array([0.1]))],
#  2007: [('role', array([0.1])),
#   ('characterization', array([0.1])),
#   ('Identification', array([0.9])),
#   ('Channel Estimation', array([0.2])),
#   ('localization', array([0.2])),
#   ('Network', array([0.1])),
#   ('estimation', array([0.2])),
#   ('Structure', array([0.2])),
#   ('evaluation', array([0.9])),
#   ('Machine Translation', array([0.3])),
#   ('classification', array([0.4])),
#   ('evaluation', array([0.1])),
#   ('Performance Evaluation', array([0.2])),
#   ('IEEE', array([0.2])),
#   ('Use', array([0.1])),
#   ('sets', array([0.3])),
#   ('sets', array([0.8])),
#   ('role', array([0.1])),
#   ('Framework', array([0.2])),
#   ('functions', array([0.3])),
#   ('model', array([0.2])),
#   ('performance', array([0.1])),
#   ('State', array([0.5])),
#   ('Modeling', array([0.3])),
#   ('Deployment', array([0.2])),
#   ('Memory', array([0.1])),
#   ('Adaptive', array([0.5])),
#   ('Models', array([0.2])),
#   ('Emergence', array([0.1])),
#   ('Performance analysis', array([0.2])),
#   ('algorithm', array([0.2])),
#   ('Segmentation', array([0.2])),
#   ('Model', array([0.4])),
#   ('Error Performance', array([0.1])),
#   ('Construction', array([0.1])),
#   ('video surveillance', array([0.1])),
#   ('monitoring', array([1.])),
#   ('Comparison', array([0.3])),
#   ('Shape', array([0.2])),
#   ('Measurement', array([0.2])),
#   ('Analysis', array([0.2])),
#   ('analysis', array([0.1])),
#   ('Delay', array([0.8])),
#   ('capacity', array([0.1])),
#   ('SLAM', array([0.2])),
#   ('Application', array([0.2])),
#   ('Wavelet', array([0.3])),
#   ('Detection', array([0.3])),
#   ('Wireless Networks', array([0.3])),
#   ('Case Study', array([0.5])),
#   ('Deployment', array([0.1])),
#   ('design', array([0.4])),
#   ('implementation', array([0.1])),
#   ('application', array([0.1])),
#   ('WLAN', array([0.1])),
#   ('Comparison', array([0.2])),
#   ('Methods', array([0.3])),
#   ('Results', array([0.4])),
#   ('Experiment', array([0.1])),
#   ('Introduction', array([0.1])),
#   ('Wireless Networks', array([0.2])),
#   ('Wireless Sensor Networks', array([0.4])),
#   ('Experiment', array([0.2])),
#   ('verification', array([0.1])),
#   ('Synthesis', array([0.3])),
#   ('use', array([0.2])),
#   ('Search', array([0.2])),
#   ('Future', array([0.1])),
#   ('Mobile', array([0.1])),
#   ('Petri Nets', array([0.2])),
#   ('Issues', array([0.2])),
#   ('Classification', array([0.1])),
#   ('computer', array([0.2])),
#   ('learning', array([0.2])),
#   ('Means', array([0.1])),
#   ('software engineering', array([0.2])),
#   ('means', array([0.1])),
#   ('Challenges', array([0.2])),
#   ('security', array([0.2])),
#   ('Efficient', array([0.1])),
#   ('Detection', array([0.1])),
#   ('strategy', array([0.2])),
#   ('Capacity', array([0.1])),
#   ('MIMO channels', array([0.1])),
#   ('presence', array([0.1])),
#   ('Application', array([0.1])),
#   ('Issues', array([0.1])),
#   ('use', array([0.1])),
#   ('OFDM Systems', array([0.1])),
#   ('Time', array([0.2])),
#   ('Location', array([0.2])),
#   ('FPGAs', array([0.1])),
#   ('Implications', array([0.1])),
#   ('Study', array([0.3])),
#   ('analysis', array([0.2])),
#   ('objects', array([0.1])),
#   ('dynamics', array([0.1])),
#   ('Retrieval', array([0.3])),
#   ('Neural Network', array([0.1])),
#   ('Use', array([0.3])),
#   ('Motion', array([0.2])),
#   ('Comparison', array([0.2])),
#   ('Presence', array([0.3])),
#   ('Description', array([0.4])),
#   ('Performance Evaluation', array([0.1])),
#   ('Tracking', array([0.4])),
#   ('tool', array([0.1])),
#   ('control', array([0.1])),
#   ('functions', array([0.2])),
#   ('Integration', array([0.1])),
#   ('Level', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('technology', array([0.1])),
#   ('Efficient', array([0.1])),
#   ('Wireless Sensor Networks', array([0.4])),
#   ('Extension', array([0.2])),
#   ('Application', array([0.1])),
#   ('IEEE', array([0.1])),
#   ('Statistical', array([0.1])),
#   ('Fast', array([0.1])),
#   ('Study', array([0.1])),
#   ('efficient algorithm', array([0.2])),
#   ('systems', array([0.1])),
#   ('database', array([0.1])),
#   ('Study', array([0.1])),
#   ('Implications', array([0.2])),
#   ('selection', array([0.1])),
#   ('Web Services', array([0.1])),
#   ('Development', array([0.2])),
#   ('FPGA', array([0.1])),
#   ('Extension', array([0.1])),
#   ('framework', array([0.2])),
#   ('application', array([0.2])),
#   ('Channel Estimation', array([0.1])),
#   ('data', array([0.2])),
#   ('Reliability', array([0.1])),
#   ('Performance Analysis', array([0.1])),
#   ('Wireless Networks', array([0.1])),
#   ('support', array([0.1])),
#   ('Evaluation', array([0.1])),
#   ('text', array([0.2])),
#   ('IEEE', array([0.1])),
#   ('performance', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('algorithm', array([0.1])),
#   ('model', array([0.1])),
#   ('knowledge', array([0.1])),
#   ('security', array([0.1])),
#   ('issues', array([0.1])),
#   ('approaches', array([0.1])),
#   ('Reliability', array([0.1])),
#   ('Applications', array([0.1])),
#   ('networks', array([0.1])),
#   ('applications', array([0.1])),
#   ('Concepts', array([0.2])),
#   ('scalability', array([0.1])),
#   ('performance', array([0.1])),
#   ('OFDM Systems', array([0.1])),
#   ('Robust', array([0.1])),
#   ('Effects', array([0.1])),
#   ('Application', array([0.1])),
#   ('Methodology', array([0.2])),
#   ('Algorithms', array([0.2])),
#   ('Impact', array([0.1])),
#   ('Effects', array([0.1])),
#   ('Application', array([0.1])),
#   ('Efficiency', array([0.1])),
#   ('Knowledge', array([0.2])),
#   ('Ontology', array([0.1])),
#   ('Performance Analysis', array([0.1])),
#   ('IEEE', array([0.1])),
#   ('Approach', array([0.1])),
#   ('Uncertainty', array([0.1])),
#   ('Application', array([0.2])),
#   ('simulation', array([0.3])),
#   ('nature', array([0.2])),
#   ('embedded systems', array([0.1])),
#   ('Construction', array([0.1])),
#   ('Performance Analysis', array([0.1])),
#   ('Design', array([0.1])),
#   ('mobile robots', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('Application', array([0.1])),
#   ('IEEE', array([0.1])),
#   ('characterization', array([0.1])),
#   ('role', array([0.1])),
#   ('Use', array([0.1])),
#   ('Selection', array([0.1])),
#   ('Information', array([0.1])),
#   ('Impact', array([0.1])),
#   ('Measurement', array([0.1])),
#   ('Class', array([0.1])),
#   ('Design', array([0.1])),
#   ('Support Vector Machines', array([0.1])),
#   ('Development', array([0.1])),
#   ('review', array([0.1])),
#   ('Segmentation', array([0.1])),
#   ('video', array([0.1])),
#   ('Deployment', array([0.1])),
#   ('Practice', array([0.1])),
#   ('Motion', array([0.1])),
#   ('construction', array([0.1])),
#   ('Evaluation', array([0.1])),
#   ('Algorithms', array([0.1])),
#   ('quality', array([0.1])),
#   ('Novel Approach', array([0.1]))],
#  2005: [('Importance', array([0.1])),
#   ('Construction', array([0.1])),
#   ('method', array([0.9])),
#   ('faults', array([0.2])),
#   ('analysis', array([0.2])),
#   ('Design', array([0.1])),
#   ('implementation', array([0.2])),
#   ('fusion', array([0.2])),
#   ('local', array([0.9])),
#   ('localization', array([0.3])),
#   ('Motion', array([0.4])),
#   ('Fusion', array([0.1])),
#   ('networks', array([0.2])),
#   ('analysis', array([0.2])),
#   ('CPM', array([0.1])),
#   ('Privacy', array([0.3])),
#   ('Development', array([0.8])),
#   ('Deployment', array([0.1])),
#   ('comparison', array([0.2])),
#   ('Method', array([0.3])),
#   ('comparison', array([0.2])),
#   ('systems', array([0.1])),
#   ('Design', array([0.5])),
#   ('systems', array([0.3])),
#   ('Development', array([0.2])),
#   ('architecture', array([0.1])),
#   ('system', array([0.5])),
#   ('real-time', array([0.2])),
#   ('ad hoc networks', array([0.1])),
#   ('implementation', array([0.2])),
#   ('Framework', array([0.2])),
#   ('Effect', array([0.2])),
#   ('algorithm', array([0.4])),
#   ('agent', array([0.1])),
#   ('architecture', array([0.1])),
#   ('Approach', array([0.1])),
#   ('Design', array([1.])),
#   ('analysis', array([0.3])),
#   ('model', array([0.2])),
#   ('efficiency', array([0.2])),
#   ('accuracy', array([0.2])),
#   ('objects', array([0.1])),
#   ('clustering', array([0.8])),
#   ('scalability', array([0.1])),
#   ('Comparative Study', array([0.2])),
#   ('Correction', array([0.2])),
#   ('computation', array([0.3])),
#   ('video', array([0.3])),
#   ('Robust', array([0.3])),
#   ('visualization', array([0.5])),
#   ('approach', array([0.1])),
#   ('application', array([0.4])),
#   ('environments', array([0.1])),
#   ('channel estimation', array([0.1])),
#   ('IT', array([0.1])),
#   ('method', array([0.2])),
#   ('application', array([0.3])),
#   ('assessment', array([0.4])),
#   ('selection', array([0.1])),
#   ('patterns', array([0.1])),
#   ('future', array([0.2])),
#   ('Evaluation', array([0.4])),
#   ('algorithm', array([0.2])),
#   ('Communication', array([0.1])),
#   ('Effects', array([0.3])),
#   ('wireless networks', array([0.2])),
#   ('application', array([0.2])),
#   ('detection', array([0.1])),
#   ('characterization', array([0.1])),
#   ('methodology', array([0.2])),
#   ('prediction', array([0.2])),
#   ('design', array([0.1])),
#   ('properties', array([0.2])),
#   ('extension', array([0.2])),
#   ('complexity', array([0.1])),
#   ('development', array([0.2])),
#   ('method', array([0.1])),
#   ('Algorithms', array([0.2])),
#   ('comparison', array([0.2])),
#   ('speech', array([0.1])),
#   ('MANETs', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('approach', array([0.1])),
#   ('support vector machine', array([0.1])),
#   ('framework', array([0.1])),
#   ('synthesis', array([0.1])),
#   ('systems', array([0.1])),
#   ('characterization', array([0.1])),
#   ('Use', array([0.1])),
#   ('Investigation', array([0.2])),
#   ('mobile robots', array([0.2])),
#   ('challenges', array([0.1])),
#   ('Comparative Study', array([0.1])),
#   ('hybrid systems', array([0.3])),
#   ('review', array([0.2])),
#   ('proposal', array([0.1])),
#   ('framework', array([0.1])),
#   ('faults', array([0.3])),
#   ('Extension', array([0.1])),
#   ('services', array([0.3])),
#   ('Overview', array([0.2])),
#   ('Design', array([0.2])),
#   ('Analysis', array([0.3])),
#   ('synthesis', array([0.4])),
#   ('applications', array([0.1])),
#   ('Performance analysis', array([0.4])),
#   ('performance', array([0.1])),
#   ('approach', array([0.1])),
#   ('effect', array([0.2])),
#   ('rate', array([0.1])),
#   ('energy', array([0.1])),
#   ('algorithm', array([0.1])),
#   ('motion', array([0.1])),
#   ('dynamics', array([0.1])),
#   ('Robust', array([0.4])),
#   ('presence', array([0.2])),
#   ('design', array([0.1])),
#   ('control', array([0.1])),
#   ('interoperability', array([0.1])),
#   ('Design', array([0.1])),
#   ('Query', array([0.1])),
#   ('Case', array([0.2])),
#   ('users', array([0.1])),
#   ('web', array([0.1])),
#   ('applications', array([0.1])),
#   ('methods', array([0.2])),
#   ('Detection', array([0.1])),
#   ('Design', array([0.1])),
#   ('context', array([0.2])),
#   ('application', array([0.1])),
#   ('Memory', array([0.1])),
#   ('scheme', array([0.2])),
#   ('applications', array([0.2])),
#   ('Experiments', array([0.1])),
#   ('Prediction', array([0.2])),
#   ('Design', array([0.1])),
#   ('services', array([0.1])),
#   ('solution', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('Role', array([0.1])),
#   ('wireless sensor networks', array([0.2])),
#   ('Evaluation', array([0.1])),
#   ('method', array([0.1])),
#   ('systems', array([0.1])),
#   ('performance', array([0.1])),
#   ('identification', array([0.1])),
#   ('nonlinear systems', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('application', array([0.1])),
#   ('transmission', array([0.1])),
#   ('transmission', array([0.1])),
#   ('context', array([0.1])),
#   ('challenges', array([0.1])),
#   ('visualization', array([0.1])),
#   ('classification', array([0.2])),
#   ('techniques', array([0.1])),
#   ('estimation', array([0.1])),
#   ('real-time', array([0.1])),
#   ('systems', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Case', array([0.1])),
#   ('Challenges', array([0.2])),
#   ('framework', array([0.2])),
#   ('survey', array([0.1])),
#   ('approach', array([0.1])),
#   ('design', array([0.1])),
#   ('software', array([0.1])),
#   ('construction', array([0.2])),
#   ('comparison', array([0.1])),
#   ('proteins', array([0.1])),
#   ('data', array([0.1])),
#   ('fusion', array([0.1])),
#   ('Part', array([0.1])),
#   ('Performance analysis', array([0.2])),
#   ('Privacy', array([0.3])),
#   ('discovery', array([0.2])),
#   ('Design', array([0.1])),
#   ('Robust', array([0.1])),
#   ('application', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('design', array([0.1])),
#   ('Verification', array([0.1])),
#   ('Visualization', array([0.1])),
#   ('machine learning', array([0.1])),
#   ('learning', array([0.1])),
#   ('scheme', array([0.1])),
#   ('evaluation', array([0.1])),
#   ('time', array([0.1])),
#   ('genes', array([0.1])),
#   ('Control', array([0.1])),
#   ('application', array([0.1])),
#   ('recognition', array([0.1])),
#   ('Learning', array([0.1])),
#   ('computation', array([0.1])),
#   ('Method', array([0.1])),
#   ('cellular networks', array([0.1])),
#   ('classification', array([0.1])),
#   ('systems', array([0.1])),
#   ('Design', array([0.1])),
#   ('Implementation', array([0.1])),
#   ('ad hoc networks', array([0.1])),
#   ('Theory', array([0.1])),
#   ('Experiences', array([0.1])),
#   ('Means', array([0.1])),
#   ('Complexity', array([0.1])),
#   ('Effects', array([0.1]))],
#  2015: [('upper bounds', array([0.1])),
#   ('networks', array([0.1])),
#   ('performance evaluation', array([0.9])),
#   ('Evaluation', array([0.2])),
#   ('survey', array([0.2])),
#   ('Assessment', array([0.1])),
#   ('effect', array([0.2])),
#   ('Internet', array([0.2])),
#   ('Case', array([0.9])),
#   ('Wireless Sensor Networks', array([0.3])),
#   ('Application', array([0.4])),
#   ('fast', array([0.1])),
#   ('efficient algorithm', array([0.2])),
#   ('Survey', array([0.2])),
#   ('Evaluation', array([0.1])),
#   ('prediction', array([0.3])),
#   ('Design', array([0.8])),
#   ('analysis', array([0.1])),
#   ('framework', array([0.2])),
#   ('Design', array([0.3])),
#   ('evaluation', array([0.2])),
#   ('knowledge', array([0.1])),
#   ('Development', array([0.5])),
#   ('Use', array([0.3])),
#   ('Determination', array([0.2])),
#   ('Learning', array([0.1])),
#   ('Methodology', array([0.5])),
#   ('wireless sensor networks', array([0.2])),
#   ('software', array([0.1])),
#   ('case study', array([0.2])),
#   ('fuzzy', array([0.2])),
#   ('applications', array([0.2])),
#   ('Systems', array([0.4])),
#   ('Bounds', array([0.1])),
#   ('uncertainty', array([0.1])),
#   ('Capacity', array([0.1])),
#   ('Wireless Networks', array([1.])),
#   ('control', array([0.3])),
#   ('technique', array([0.2])),
#   ('recognition', array([0.2])),
#   ('models', array([0.2])),
#   ('Performance analysis', array([0.1])),
#   ('Comparison', array([0.8])),
#   ('OFDM', array([0.1])),
#   ('Implementation', array([0.2])),
#   ('influence', array([0.2])),
#   ('Novel Approach', array([0.3])),
#   ('interactions', array([0.3])),
#   ('graphs', array([0.3])),
#   ('wireless sensor networks', array([0.5])),
#   ('analysis', array([0.1])),
#   ('search', array([0.4])),
#   ('Analysis', array([0.1])),
#   ('Cryptanalysis', array([0.1])),
#   ('Image', array([0.1])),
#   ('navigation', array([0.2])),
#   ('Challenges', array([0.3])),
#   ('reliability', array([0.4])),
#   ('diffusion', array([0.1])),
#   ('measures', array([0.1])),
#   ('Classification', array([0.2])),
#   ('Sensitivity', array([0.4])),
#   ('Evidence', array([0.2])),
#   ('Cryptanalysis', array([0.1])),
#   ('classification', array([0.3])),
#   ('new method', array([0.2])),
#   ('recognition', array([0.2])),
#   ('use', array([0.1])),
#   ('tool', array([0.1])),
#   ('results', array([0.2])),
#   ('Design', array([0.2])),
#   ('Calibration', array([0.1])),
#   ('communication', array([0.2])),
#   ('challenges', array([0.2])),
#   ('evaluation', array([0.1])),
#   ('Effects', array([0.2])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('control', array([0.2])),
#   ('constraints', array([0.2])),
#   ('children', array([0.1])),
#   ('field', array([0.1])),
#   ('study', array([0.2])),
#   ('Benefits', array([0.1])),
#   ('Role', array([0.1])),
#   ('Evolution', array([0.1])),
#   ('application', array([0.1])),
#   ('sensor networks', array([0.1])),
#   ('approach', array([0.1])),
#   ('Methods', array([0.1])),
#   ('Neural Networks', array([0.2])),
#   ('registration', array([0.2])),
#   ('Impact', array([0.1])),
#   ('implementation', array([0.1])),
#   ('application', array([0.3])),
#   ('VANETs', array([0.2])),
#   ('diffusion', array([0.1])),
#   ('survey', array([0.1])),
#   ('solutions', array([0.3])),
#   ('note', array([0.1])),
#   ('Construction', array([0.3])),
#   ('Methods', array([0.2])),
#   ('applications', array([0.2])),
#   ('Introduction', array([0.3])),
#   ('special issue', array([0.4])),
#   ('k', array([0.1])),
#   ('Query', array([0.4])),
#   ('example', array([0.1])),
#   ('future', array([0.1])),
#   ('Images', array([0.2])),
#   ('Assessment', array([0.1])),
#   ('China', array([0.1])),
#   ('Cloud', array([0.1])),
#   ('Measurements', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Semantics', array([0.4])),
#   ('performance', array([0.2])),
#   ('Survey', array([0.1])),
#   ('Emergence', array([0.1])),
#   ('field', array([0.1])),
#   ('Neural Network', array([0.1])),
#   ('Evidence', array([0.1])),
#   ('Bounds', array([0.2])),
#   ('implementation', array([0.1])),
#   ('scheme', array([0.1]))],
#  2013: [('design', array([0.1])),
#   ('FPGAs', array([0.1])),
#   ('Optimization', array([0.9])),
#   ('web server', array([0.2])),
#   ('Novel Approach', array([0.2])),
#   ('Determination', array([0.1])),
#   ('system', array([0.2])),
#   ('diffusion', array([0.2])),
#   ('survey', array([0.9])),
#   ('applications', array([0.3])),
#   ('optimization', array([0.4])),
#   ('Design', array([0.1])),
#   ('change', array([0.2])),
#   ('system', array([0.2])),
#   ('Clusters', array([0.1])),
#   ('software engineering', array([0.3])),
#   ('study', array([0.8])),
#   ('survey', array([0.1])),
#   ('Implementation', array([0.2])),
#   ('Verification', array([0.3])),
#   ('State', array([0.2])),
#   ('integration', array([0.1])),
#   ('regions', array([0.5])),
#   ('construction', array([0.3])),
#   ('Cognitive Radio Networks', array([0.2])),
#   ('presence', array([0.1])),
#   ('Implications', array([0.5])),
#   ('system', array([0.2])),
#   ('Cognitive Radio Networks', array([0.1])),
#   ('Characterization', array([0.2])),
#   ('Models', array([0.2])),
#   ('applications', array([0.2])),
#   ('services', array([0.4])),
#   ('information systems', array([0.1])),
#   ('development', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Application', array([1.])),
#   ('social network', array([0.3])),
#   ('parallel', array([0.2])),
#   ('existence', array([0.2])),
#   ('construction', array([0.2])),
#   ('management', array([0.1])),
#   ('services', array([0.8])),
#   ('Internet', array([0.1])),
#   ('systems', array([0.2])),
#   ('effects', array([0.2])),
#   ('interaction', array([0.3])),
#   ('Generation', array([0.3])),
#   ('Comparative Study', array([0.3])),
#   ('scheme', array([0.5])),
#   ('capacity', array([0.1])),
#   ('classification', array([0.4])),
#   ('proteins', array([0.1])),
#   ('impact', array([0.1])),
#   ('Effect', array([0.1])),
#   ('objects', array([0.2])),
#   ('system', array([0.3])),
#   ('ontologies', array([0.4])),
#   ('practice', array([0.1])),
#   ('methods', array([0.1])),
#   ('applications', array([0.2])),
#   ('security', array([0.4])),
#   ('vision', array([0.2])),
#   ('number', array([0.1])),
#   ('problem', array([0.3])),
#   ('upper bounds', array([0.2])),
#   ('analysis', array([0.2])),
#   ('Theory', array([0.1])),
#   ('Algorithm', array([0.1])),
#   ('Performance Analysis', array([0.2])),
#   ('classification', array([0.2])),
#   ('Query', array([0.1])),
#   ('Secure', array([0.2])),
#   ('Algorithm', array([0.2])),
#   ('detection', array([0.1])),
#   ('Users', array([0.2])),
#   ('Case Study', array([0.1])),
#   ('review', array([0.2])),
#   ('Evaluation', array([0.2])),
#   ('Communication', array([0.1])),
#   ('agents', array([0.1])),
#   ('interoperability', array([0.2])),
#   ('problem', array([0.1])),
#   ('scheduling', array([0.1])),
#   ('Effects', array([0.1])),
#   ('Web Services', array([0.1])),
#   ('effect', array([0.1])),
#   ('performance', array([0.1])),
#   ('systems', array([0.1])),
#   ('performance', array([0.2])),
#   ('neural networks', array([0.2])),
#   ('Segmentation', array([0.1])),
#   ('proteins', array([0.1])),
#   ('presence', array([0.3])),
#   ('graphs', array([0.2])),
#   ('compression', array([0.1])),
#   ('control systems', array([0.1])),
#   ('presence', array([0.3])),
#   ('empirical study', array([0.1])),
#   ('Simulation', array([0.3])),
#   ('experiments', array([0.2])),
#   ('analysis', array([0.2])),
#   ('Twitter', array([0.3])),
#   ('Use', array([0.4])),
#   ('Performance evaluation', array([0.1])),
#   ('Design', array([0.4])),
#   ('survey', array([0.1])),
#   ('Method', array([0.1])),
#   ('stability', array([0.2])),
#   ('segmentation', array([0.1])),
#   ('novel approach', array([0.1])),
#   ('Internet', array([0.1])),
#   ('Cognitive Radio Networks', array([0.1])),
#   ('level', array([0.1])),
#   ('Identification', array([0.4])),
#   ('characterization', array([0.2])),
#   ('machine learning', array([0.1])),
#   ('RFID', array([0.1])),
#   ('robustness', array([0.1])),
#   ('Part', array([0.1])),
#   ('implications', array([0.1])),
#   ('multicast', array([0.2])),
#   ('Measurements', array([0.1])),
#   ('Effects', array([0.1])),
#   ('Towards', array([0.1])),
#   ('level', array([0.2])),
#   ('energy', array([0.1])),
#   ('Strategies', array([0.1])),
#   ('Towards', array([0.2])),
#   ('optimization', array([0.1])),
#   ('dynamic environments', array([0.1])),
#   ('influence', array([0.2])),
#   ('social networks', array([0.2])),
#   ('Assessment', array([0.1])),
#   ('Review', array([0.2])),
#   ('effect', array([0.1])),
#   ('diffusion', array([0.1])),
#   ('social media', array([0.1])),
#   ('OFDM systems', array([0.1])),
#   ('OFDM Systems', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('Uncertainty', array([0.1])),
#   ('Survey', array([0.1])),
#   ('Importance', array([0.1])),
#   ('tool', array([0.1])),
#   ('Impact', array([0.1])),
#   ('Implications', array([0.1])),
#   ('uncertainty', array([0.1])),
#   ('accuracy', array([0.1])),
#   ('diversity', array([0.1])),
#   ('Level', array([0.1])),
#   ('evolution', array([0.1])),
#   ('image segmentation', array([0.1])),
#   ('Collaboration', array([0.1])),
#   ('time', array([0.2])),
#   ('architecture', array([0.1])),
#   ('Algorithm', array([0.1])),
#   ('Benefits', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Application', array([0.1])),
#   ('energy', array([0.1])),
#   ('power', array([0.2])),
#   ('simulation', array([0.2])),
#   ('Exploration', array([0.1])),
#   ('web server', array([0.1])),
#   ('identification', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('Influence', array([0.2])),
#   ('performance', array([0.1])),
#   ('Ontology', array([0.1])),
#   ('selection', array([0.1])),
#   ('Technology', array([0.1])),
#   ('Design', array([0.1])),
#   ('trust', array([0.2])),
#   ('Wireless Sensor Networks', array([0.3])),
#   ('quality', array([0.2])),
#   ('social media', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('effects', array([0.1])),
#   ('Validation', array([0.1])),
#   ('Application', array([0.1])),
#   ('classification', array([0.1])),
#   ('data', array([0.1])),
#   ('review', array([0.1])),
#   ('redundancy', array([0.1])),
#   ('applications', array([0.1])),
#   ('evaluation', array([0.1])),
#   ('hybrid systems', array([0.1])),
#   ('assessment', array([0.1])),
#   ('new approach', array([0.1])),
#   ('Evaluation', array([0.1])),
#   ('graphs', array([0.1])),
#   ('sets', array([0.1])),
#   ('points', array([0.1])),
#   ('Scalable', array([0.1])),
#   ('Distributed', array([0.1])),
#   ('Memory', array([0.1])),
#   ('Graphs', array([0.1])),
#   ('Evaluation', array([0.1])),
#   ('Systems', array([0.1])),
#   ('Applications', array([0.1])),
#   ('objects', array([0.1])),
#   ('Classification', array([0.1])),
#   ('wavelet transform', array([0.1])),
#   ('social networks', array([0.1])),
#   ('comparison', array([0.1]))],
#  1998: [('schemes', array([0.1])),
#   ('time', array([0.1])),
#   ('Design', array([0.9])),
#   ('Algorithm', array([0.2])),
#   ('people', array([0.2])),
#   ('motion estimation', array([0.1])),
#   ('Use', array([0.2])),
#   ('Analysis', array([0.2])),
#   ('approaches', array([0.9])),
#   ('Effectiveness', array([0.3])),
#   ('Performance', array([0.4])),
#   ('simulation', array([0.1])),
#   ('Effect', array([0.2])),
#   ('dynamics', array([0.2])),
#   ('segmentation', array([0.1])),
#   ('Development', array([0.3])),
#   ('MIMO channels', array([0.8])),
#   ('Complexity', array([0.1])),
#   ('control', array([0.2])),
#   ('Performance evaluation', array([0.3])),
#   ('Estimation', array([0.2])),
#   ('Identification', array([0.1])),
#   ('Reconstruction', array([0.5])),
#   ('Motion', array([0.3])),
#   ('construction', array([0.2])),
#   ('Class', array([0.1])),
#   ('approach', array([0.5])),
#   ('graphs', array([0.2])),
#   ('recognition', array([0.1])),
#   ('part', array([0.2])),
#   ('technology', array([0.2])),
#   ('Optimization', array([0.2])),
#   ('Recognition', array([0.4])),
#   ('real-time', array([0.1])),
#   ('control systems', array([0.1])),
#   ('Evolution', array([0.1])),
#   ('images', array([1.])),
#   ('data', array([0.3])),
#   ('Design', array([0.2])),
#   ('Application', array([0.2])),
#   ('performance', array([0.2])),
#   ('presence', array([0.1])),
#   ('Education', array([0.8])),
#   ('Web', array([0.1])),
#   ('Students', array([0.2])),
#   ('Training', array([0.2])),
#   ('design', array([0.3])),
#   ('video', array([0.3])),
#   ('synthesis', array([0.3])),
#   ('systems', array([0.5])),
#   ('simulation', array([0.1])),
#   ('simulation', array([0.4])),
#   ('interactions', array([0.1])),
#   ('class', array([0.1])),
#   ('construction', array([0.1])),
#   ('design', array([0.2])),
#   ('comparison', array([0.3])),
#   ('Segmentation', array([0.4])),
#   ('verification', array([0.1])),
#   ('validation', array([0.1])),
#   ('system', array([0.2]))],
#  2014: [('impact', array([0.1])),
#   ('solution', array([0.1])),
#   ('model', array([0.9])),
#   ('influence', array([0.2])),
#   ('analysis', array([0.2])),
#   ('performance', array([0.1])),
#   ('Introduction', array([0.2])),
#   ('GPU', array([0.2])),
#   ('genes', array([0.9])),
#   ('Effects', array([0.3])),
#   ('algorithm', array([0.4])),
#   ('Knowledge', array([0.1])),
#   ('Architecture', array([0.2])),
#   ('parallel', array([0.2])),
#   ('Security', array([0.1])),
#   ('Evolution', array([0.3])),
#   ('algorithm', array([0.8])),
#   ('complexity', array([0.1])),
#   ('behaviour', array([0.2])),
#   ('implementation', array([0.3])),
#   ('control', array([0.2])),
#   ('Survey', array([0.1])),
#   ('approach', array([0.5])),
#   ('presence', array([0.3])),
#   ('efficiency', array([0.2])),
#   ('Assessment', array([0.1])),
#   ('algorithm', array([0.5])),
#   ('Robust', array([0.2])),
#   ('detection', array([0.1])),
#   ('framework', array([0.2])),
#   ('Adaptive', array([0.2])),
#   ('Determination', array([0.2])),
#   ('Theory', array([0.4])),
#   ('Application', array([0.1])),
#   ('IEEE', array([0.1])),
#   ('Study', array([0.1])),
#   ('Effects', array([1.])),
#   ('graphs', array([0.3])),
#   ('study', array([0.2])),
#   ('Experience', array([0.2])),
#   ('Influence', array([0.2])),
#   ('Effect', array([0.1])),
#   ('Recognition', array([0.8])),
#   ('Control', array([0.1])),
#   ('localization', array([0.2])),
#   ('Design', array([0.2])),
#   ('Evaluation', array([0.3])),
#   ('detection', array([0.3])),
#   ('behavior', array([0.3])),
#   ('Secure', array([0.5])),
#   ('decomposition', array([0.1])),
#   ('Comparison', array([0.4])),
#   ('schemes', array([0.1])),
#   ('Modeling', array([0.1])),
#   ('design', array([0.1])),
#   ('Data', array([0.2])),
#   ('evolution', array([0.3])),
#   ('Access', array([0.4])),
#   ('use', array([0.1])),
#   ('research', array([0.1])),
#   ('survey', array([0.2])),
#   ('Detection', array([0.4])),
#   ('Optimization', array([0.2])),
#   ('decomposition', array([0.1])),
#   ('evolution', array([0.3])),
#   ('Use', array([0.2])),
#   ('selection', array([0.2])),
#   ('empirical study', array([0.1])),
#   ('Face Recognition', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('effects', array([0.2])),
#   ('Overview', array([0.1])),
#   ('Towards', array([0.2])),
#   ('Cloud', array([0.2])),
#   ('Evaluation', array([0.1])),
#   ('users', array([0.2])),
#   ('web', array([0.1])),
#   ('behavior', array([0.2])),
#   ('Bounds', array([0.2])),
#   ('Cloud', array([0.1])),
#   ('proteins', array([0.1])),
#   ('cellular networks', array([0.2])),
#   ('Inference', array([0.1])),
#   ('comparison', array([0.1])),
#   ('models', array([0.1])),
#   ('note', array([0.1])),
#   ('speech', array([0.1])),
#   ('visualization', array([0.1])),
#   ('analysis', array([0.1])),
#   ('behavior', array([0.2])),
#   ('Survey', array([0.2])),
#   ('power', array([0.1])),
#   ('Shape', array([0.1])),
#   ('software', array([0.3])),
#   ('video', array([0.2])),
#   ('Law', array([0.1])),
#   ('new method', array([0.1])),
#   ('motion', array([0.3])),
#   ('Detection', array([0.1])),
#   ('classification', array([0.3])),
#   ('China', array([0.2])),
#   ('research', array([0.2])),
#   ('Introduction', array([0.3])),
#   ('Cloud', array([0.4])),
#   ('case study', array([0.1])),
#   ('Cryptanalysis', array([0.4])),
#   ('Control', array([0.1])),
#   ('simulation', array([0.1])),
#   ('strategy', array([0.2])),
#   ('dynamic', array([0.1])),
#   ('Evolution', array([0.1])),
#   ('classification', array([0.1])),
#   ('review', array([0.1])),
#   ('novel approach', array([0.1])),
#   ('Effectiveness', array([0.4])),
#   ('application', array([0.2])),
#   ('approach', array([0.1])),
#   ('context', array([0.1])),
#   ('embedded systems', array([0.1])),
#   ('software engineering', array([0.1])),
#   ('Experience', array([0.1])),
#   ('Machine Translation', array([0.2])),
#   ('Application', array([0.1])),
#   ('Wireless Networks', array([0.1])),
#   ('Structure', array([0.1])),
#   ('Benefits', array([0.2])),
#   ('Application', array([0.1])),
#   ('video', array([0.1])),
#   ('algorithm', array([0.2])),
#   ('application', array([0.1])),
#   ('Collaboration', array([0.1])),
#   ('database', array([0.2])),
#   ('Investigation', array([0.2])),
#   ('Vision', array([0.1])),
#   ('Integration', array([0.2])),
#   ('challenges', array([0.1])),
#   ('case', array([0.1])),
#   ('future', array([0.1])),
#   ('software engineering', array([0.1])),
#   ('survey', array([0.1])),
#   ('method', array([0.2])),
#   ('application', array([0.1])),
#   ('Throughput', array([0.1])),
#   ('detection', array([0.1])),
#   ('tracking', array([0.1])),
#   ('role', array([0.1])),
#   ('technique', array([0.1])),
#   ('properties', array([0.1])),
#   ('compression', array([0.1])),
#   ('Construction', array([0.1])),
#   ('effects', array([0.1])),
#   ('Security', array([0.1])),
#   ('functions', array([0.1])),
#   ('Power', array([0.1])),
#   ('use', array([0.2])),
#   ('Learning', array([0.1])),
#   ('Case', array([0.1])),
#   ('Structure', array([0.1])),
#   ('dynamics', array([0.1])),
#   ('Software', array([0.1])),
#   ('Access', array([0.1])),
#   ('schemes', array([0.2])),
#   ('application', array([0.2])),
#   ('search', array([0.1])),
#   ('Effect', array([0.1])),
#   ('proposal', array([0.1])),
#   ('China', array([0.1])),
#   ('Segmentation', array([0.2])),
#   ('Effect', array([0.1])),
#   ('Twitter', array([0.1])),
#   ('Performance evaluation', array([0.1])),
#   ('Computation', array([0.1])),
#   ('video surveillance', array([0.1]))],
#  2009: [('applications', array([0.1])),
#   ('ad hoc networks', array([0.1])),
#   ('children', array([0.9])),
#   ('comparison', array([0.2])),
#   ('challenges', array([0.2])),
#   ('FPGAs', array([0.1])),
#   ('Benefits', array([0.2])),
#   ('Technology', array([0.2])),
#   ('Evolution', array([0.9])),
#   ('control systems', array([0.3])),
#   ('Design', array([0.4])),
#   ('Implementation', array([0.1])),
#   ('Wireless Networks', array([0.2])),
#   ('technique', array([0.2])),
#   ('architecture', array([0.1])),
#   ('evaluation', array([0.3])),
#   ('Accurate', array([0.8])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Effectiveness', array([0.2])),
#   ('Machine Translation', array([0.3])),
#   ('Mobile', array([0.2])),
#   ('database', array([0.1])),
#   ('Design', array([0.5])),
#   ('Case', array([0.3])),
#   ('Verification', array([0.2])),
#   ('cloud', array([0.1])),
#   ('Performance', array([0.5])),
#   ('Robust', array([0.2])),
#   ('Routing', array([0.1])),
#   ('Mobile Ad Hoc Networks', array([0.2])),
#   ('Development', array([0.2])),
#   ('extension', array([0.2])),
#   ('Network', array([0.4])),
#   ('software', array([0.1])),
#   ('Approach', array([0.1])),
#   ('estimation', array([0.1])),
#   ('wireless sensor networks', array([1.])),
#   ('Optimization', array([0.3])),
#   ('search', array([0.2])),
#   ('Requirements', array([0.2])),
#   ('Education', array([0.2])),
#   ('Training', array([0.1])),
#   ('Performance Analysis', array([0.8])),
#   ('Research', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('use', array([0.2])),
#   ('Implementation', array([0.3])),
#   ('evaluation', array([0.3])),
#   ('support vector machine', array([0.3])),
#   ('Knowledge', array([0.5])),
#   ('system', array([0.1])),
#   ('Estimation', array([0.4])),
#   ('application', array([0.1])),
#   ('Design', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('performance', array([0.2])),
#   ('Experiments', array([0.3])),
#   ('Evaluation', array([0.4])),
#   ('Privacy', array([0.1])),
#   ('Features', array([0.1])),
#   ('approach', array([0.2])),
#   ('presence', array([0.4])),
#   ('empirical study', array([0.2])),
#   ('Design', array([0.1])),
#   ('web', array([0.3])),
#   ('agents', array([0.2])),
#   ('Study', array([0.2])),
#   ('Introduction', array([0.1])),
#   ('special issue', array([0.1])),
#   ('evolution', array([0.2])),
#   ('Performance', array([0.2])),
#   ('transmission', array([0.1])),
#   ('linear', array([0.2])),
#   ('Tracking', array([0.2])),
#   ('capacity', array([0.1])),
#   ('security', array([0.2])),
#   ('Classification', array([0.1])),
#   ('Complexity', array([0.2])),
#   ('Design', array([0.2])),
#   ('policies', array([0.1])),
#   ('real-time', array([0.1])),
#   ('Assessment', array([0.2])),
#   ('Evaluation', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Improvement', array([0.1])),
#   ('Design', array([0.1])),
#   ('Implementation', array([0.1])),
#   ('resources', array([0.1])),
#   ('Computation', array([0.1])),
#   ('Performance evaluation', array([0.2])),
#   ('IEEE', array([0.2])),
#   ('policies', array([0.1])),
#   ('throughput', array([0.1])),
#   ('Application', array([0.3])),
#   ('Segmentation', array([0.2])),
#   ('Efficient', array([0.1])),
#   ('robustness', array([0.1])),
#   ('protocol', array([0.3])),
#   ('Novel Approach', array([0.1])),
#   ('Development', array([0.3])),
#   ('Application', array([0.2])),
#   ('Wireless Sensor Networks', array([0.2])),
#   ('Impact', array([0.3])),
#   ('Security', array([0.4])),
#   ('Performance', array([0.1])),
#   ('Approximation', array([0.4])),
#   ('Identification', array([0.1])),
#   ('Class', array([0.1])),
#   ('Systems', array([0.2])),
#   ('Novel Approach', array([0.1])),
#   ('Images', array([0.1])),
#   ('use', array([0.1])),
#   ('architecture', array([0.1])),
#   ('Web', array([0.1])),
#   ('application', array([0.4])),
#   ('Communication', array([0.2])),
#   ('Calibration', array([0.1])),
#   ('Design', array([0.1])),
#   ('experiences', array([0.1])),
#   ('video surveillance', array([0.1])),
#   ('robots', array([0.1])),
#   ('Image', array([0.2])),
#   ('accuracy', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('protein', array([0.1])),
#   ('accuracy', array([0.2])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Applications', array([0.1])),
#   ('practice', array([0.2])),
#   ('Comparison', array([0.1])),
#   ('Stability', array([0.1])),
#   ('Design', array([0.2])),
#   ('IEEE', array([0.2])),
#   ('networks', array([0.1])),
#   ('Optimization', array([0.2])),
#   ('comparative study', array([0.1])),
#   ('hybrid systems', array([0.1])),
#   ('motion', array([0.1])),
#   ('Research', array([0.1])),
#   ('Towards', array([0.1])),
#   ('Introduction', array([0.2])),
#   ('Integration', array([0.1])),
#   ('Routing', array([0.1])),
#   ('Research', array([0.1])),
#   ('implementation', array([0.1])),
#   ('Localization', array([0.1])),
#   ('Wireless Sensor Networks', array([0.1])),
#   ('Adaptive', array([0.1])),
#   ('solution', array([0.1])),
#   ('wireless sensor networks', array([0.1])),
#   ('Fast', array([0.1])),
#   ('Efficient', array([0.1])),
#   ('users', array([0.1])),
#   ('Research', array([0.1])),
#   ('Design', array([0.2])),
#   ('Evaluation', array([0.1])),
#   ('case study', array([0.1])),
#   ('Analysis', array([0.1])),
#   ('Integration', array([0.1])),
#   ('Shape', array([0.1])),
#   ('Design', array([0.1])),
#   ('class', array([0.2])),
#   ('methodology', array([0.2])),
#   ('implementation', array([0.1])),
#   ('MANETs', array([0.1])),
#   ('Development', array([0.1])),
#   ('Mobile Ad Hoc Networks', array([0.1])),
#   ('Performance Analysis', array([0.2])),
#   ('Routing', array([0.1])),
#   ('Application', array([0.1])),
#   ('Evaluation', array([0.1])),
#   ('impact', array([0.1])),
#   ('Collaboration', array([0.1])),
#   ('Localization', array([0.2])),
#   ('Capacity', array([0.3])),
#   ('Comparison', array([0.2])),
#   ('integration', array([0.1])),
#   ('Privacy', array([0.1])),
#   ('analysis', array([0.1])),
#   ('parallel', array([0.1])),
#   ('methods', array([0.1])),
#   ('transmission', array([0.1])),
#   ('knowledge', array([0.1])),
#   ('Importance', array([0.1])),
#   ('Applications', array([0.1])),
#   ('Methodology', array([0.1])),
#   ('Experience', array([0.1])),
#   ('Design', array([0.1])),
#   ('Performance Analysis', array([0.1])),
#   ('progress report', array([0.1])),
#   ('Methodology', array([0.1])),
#   ('role', array([0.1])),
#   ('Research', array([0.1])),
#   ('use', array([0.1])),
#   ('method', array([0.1])),
#   ('wireless networks', array([0.1])),
#   ('Approximation', array([0.1])),
#   ('Channel', array([0.1])),
#   ('algorithms', array([0.1])),
#   ('Efficient', array([0.1])),
#   ('Memory', array([0.1])),
#   ('Strategies', array([0.1])),
#   ('effects', array([0.1])),
#   ('Characterization', array([0.1])),
#   ('Error Performance', array([0.1])),
#   ('Presence', array([0.1]))],
#  2010: [('accuracy', array([0.1])),
#   ('sensor networks', array([0.1])),
#   ('Control', array([0.9])),
#   ('model', array([0.2])),
#   ('case study', array([0.2])),
#   ('Performance', array([0.1])),
#   ('requirements', array([0.2])),
#   ('approach', array([0.2])),
#   ('verification', array([0.9])),
#   ('diagnosis', array([0.3])),
#   ('influence', array([0.4])),
#   ('Performance analysis', array([0.1])),
#   ('case', array([0.2])),
#   ('sets', array([0.2])),
#   ('Presence', array([0.1])),
#   ('management', array([0.3])),
#   ('Reliability', array([0.8])),
#   ('evaluation', array([0.1])),
#   ('social networks', array([0.2])),
#   ('influence', array([0.3])),
#   ('segmentation', array([0.2])),
#   ('Use', array([0.1])),
#   ('interoperability', array([0.5])),
#   ('Cloud', array([0.3])),
#   ('computation', array([0.2])),
#   ('IEEE', array([0.1])),
#   ('Theory', array([0.5])),
#   ('Measurement', array([0.2])),
#   ('structure', array([0.1])),
#   ('scheme', array([0.2])),
#   ('Performance Analysis', array([0.2])),
#   ('Inference', array([0.2])),
#   ('Use', array([0.4])),
#   ('estimation', array([0.1])),
#   ('OFDM', array([0.1])),
#   ('application', array([0.1])),
#   ('example', array([1.])),
#   ('comparison', array([0.3])),
#   ('Twitter', array([0.2])),
#   ('technology', array([0.2])),
#   ('analysis', array([0.2])),
#   ('Detection', array([0.1])),
#   ('networks', array([0.8])),
#   ('redundancy', array([0.1])),
#   ('learning', array([0.2])),
#   ('effect', array([0.2])),
#   ('Investigation', array([0.3])),
#   ('optimization', array([0.3])),
#   ('control', array([0.3])),
#   ('Prediction', array([0.5])),
#   ('case study', array([0.1])),
#   ('Neural Network', array([0.4])),
#   ('Simulation', array([0.1])),
#   ('GPU', array([0.1])),
#   ('Number', array([0.1])),
#   ('dynamic', array([0.2])),
#   ('estimation', array([0.3])),
#   ('Efficient', array([0.4])),
#   ('Model', array([0.1])),
#   ('Reliability', array([0.1])),
#   ('Development', array([0.2])),
#   ('characterization', array([0.4])),
#   ('capacity', array([0.2])),
#   ('constraints', array([0.1])),
#   ('optimization', array([0.3])),
#   ('systems', array([0.2])),
#   ('environments', array([0.2])),
#   ('Image', array([0.1])),
#   ('case', array([0.1])),
#   ('prediction', array([0.2])),
#   ('novel approach', array([0.2])),
#   ('case study', array([0.1])),
#   ('IEEE', array([0.2])),
#   ('networks', array([0.2])),
#   ('Support Vector Machines', array([0.1])),
#   ('Stability', array([0.2])),
#   ('Search', array([0.1])),
#   ('validation', array([0.2])),
#   ('analysis', array([0.2])),
#   ('systems', array([0.1])),
#   ('Control', array([0.1])),
#   ('Impact', array([0.2])),
#   ('Performance', array([0.1])),
#   ('scheme', array([0.1])),
#   ('effect', array([0.1])),
#   ('Segmentation', array([0.1])),
#   ('Inference', array([0.1])),
#   ('Framework', array([0.1])),
#   ('Performance Analysis', array([0.1])),
#   ('Algorithm', array([0.2])),
#   ('Reconstruction', array([0.2])),
#   ('comparison', array([0.1])),
#   ('representation', array([0.1])),
#   ('Implementation', array([0.3])),
#   ('dynamics', array([0.2])),
#   ('Extraction', array([0.1])),
#   ('Capacity', array([0.1])),
#   ('class', array([0.3])),
#   ('implementation', array([0.1])),
#   ('Architecture', array([0.3])),
#   ('mobile devices', array([0.2])),
#   ('software', array([0.2])),
#   ('human', array([0.3])),
#   ('Towards', array([0.4])),
#   ('Theory', array([0.1])),
#   ('Application', array([0.4])),
#   ('web', array([0.1])),
#   ('comparison', array([0.1])),
#   ('Algorithms', array([0.2])),
#   ('Technology', array([0.1])),
#   ('system', array([0.1])),
#   ('application', array([0.1])),
#   ('Construction', array([0.1])),
#   ('Use', array([0.1])),
#   ('Influence', array([0.4])),
#   ('dynamic', array([0.2])),
#   ('selection', array([0.1])),
#   ('Cognitive Radio Networks', array([0.1])),
#   ('OFDM', array([0.1])),
#   ('approach', array([0.1])),
#   ('motion', array([0.1])),
#   ('Role', array([0.2])),
#   ('Comparison', array([0.1])),
#   ('strategies', array([0.1])),
#   ('Evidence', array([0.1])),
#   ('challenges', array([0.2])),
#   ('Training', array([0.1])),
#   ('applications', array([0.1])),
#   ('note', array([0.2])),
#   ('Performance', array([0.1])),
# ...
#   ('ontologies', array([0.1])),
#   ('identification', array([0.2])),
#   ('new approach', array([0.3])),
#   ('novel approach', array([0.4])),
#   ('estimation', array([0.1])),
#   ('accurate', array([0.1])),
#   ('use', array([0.2])),
#   ('Emergence', array([0.4])),
#   ('II', array([0.2])),
#   ('Policies', array([0.1])),
#   ('Research', array([0.3])),
#   ('analysis', array([0.2])),
#   ('Design', array([0.2])),
#   ('Cloud', array([0.1])),
#   ('time', array([0.1])),
#   ('cluster', array([0.2])),
#   ('Robust', array([0.2])),
#   ('patterns', array([0.1])),
#   ('Analysis', array([0.2])),
#   ('Identification', array([0.2])),
#   ('new method', array([0.1])),
#   ('identification', array([0.2])),
#   ('Control', array([0.1])),
#   ('Privacy', array([0.2])),
#   ('Data', array([0.2])),
#   ('Clouds', array([0.1])),
#   ('tool', array([0.1])),
#   ('analysis', array([0.2])),
#   ('visualization', array([0.1])),
#   ('Design', array([0.1])),
#   ('Towards', array([0.1])),
#   ('users', array([0.1])),
#   ('objects', array([0.1])),
#   ('images', array([0.1])),
#   ('problem', array([0.1])),
#   ('compression', array([0.2])),
#   ('embedded systems', array([0.2])),
#   ('Prediction', array([0.1])),
#   ('framework', array([0.1])),
#   ('data mining', array([0.3])),
#   ('power', array([0.2])),
#   ('performance', array([0.1])),
#   ('case study', array([0.1])),
#   ('wireless networks', array([0.3])),
#   ('Analysis', array([0.1])),
#   ('Framework', array([0.3])),
#   ('Privacy', array([0.2])),
#   ('images', array([0.2])),
#   ('framework', array([0.3])),
#   ('n', array([0.4])),
#   ('diffusion', array([0.1])),
#   ('Challenges', array([0.4])),
#   ('genes', array([0.1])),
#   ('influence', array([0.1])),
#   ('systems', array([0.2])),
#   ('evaluation', array([0.1])),
#   ('diagnosis', array([0.1])),
#   ('management', array([0.1])),
#   ('constraints', array([0.1])),
#   ('design', array([0.1])),
#   ('Architecture', array([0.4])),
#   ('protocol', array([0.2])),
#   ('video', array([0.1])),
#   ('mobile devices', array([0.1])),
#   ('Control', array([0.1])),
#   ('performance', array([0.1])),
#   ('Simulation', array([0.1])),
#   ('Impact', array([0.2])),
#   ('use', array([0.1])),
#   ('Simulation', array([0.1])),
#   ('learning', array([0.1])),
#   ('dynamics', array([0.2])),
#   ('case study', array([0.1])),
#   ('design', array([0.1])),
#   ('implementation', array([0.2])),
#   ('design', array([0.1])),
#   ('analysis', array([0.1])),
#   ('empirical study', array([0.2])),
#   ('Application', array([0.2])),
#   ('Education', array([0.1])),
#   ('Study', array([0.2])),
#   ('Performance', array([0.1])),
#   ('experimental evaluation', array([0.1])),
#   ('Construction', array([0.1])),
#   ('practice', array([0.1])),
#   ('learning', array([0.1])),
#   ('Introduction', array([0.2])),
#   ('Special Issue', array([0.1])),
#   ('Emergence', array([0.1])),
#   ('Impact', array([0.1])),
#   ('Optimization', array([0.1])),
#   ('Identification', array([0.1])),
#   ('modeling', array([0.1])),
#   ('reconstruction', array([0.1])),
#   ('systems', array([0.1])),
#   ('Identification', array([0.1])),
#   ('Approximation', array([0.1])),
#   ('overview', array([0.1])),
#   ('impact', array([0.1])),
#   ('application', array([0.1])),
#   ('neural networks', array([0.2])),
#   ('algorithms', array([0.1])),
#   ('visualization', array([0.1])),
#   ('ontologies', array([0.1])),
#   ('Requirements', array([0.1])),
#   ('Generation', array([0.1])),
#   ('Effect', array([0.1])),
#   ('Internet', array([0.2])),
#   ('approach', array([0.2])),
#   ('role', array([0.1])),
#   ('application', array([0.1])),
#   ('Comparison', array([0.1])),
#   ('Experiences', array([0.1])),
#   ('role', array([0.2])),
#   ('software', array([0.1])),
#   ('interaction', array([0.1])),
#   ('Simulation', array([0.1])),
#   ('model', array([0.1])),
#   ('Vision', array([0.1])),
#   ('Tracking', array([0.2])),
#   ('children', array([0.3])),
#   ('Identification', array([0.2])),
#   ('Systems', array([0.1])),
#   ('application', array([0.1])),
#   ('Challenges', array([0.1])),
#   ('Segmentation', array([0.1])),
#   ('problems', array([0.1])),
#   ('dynamic environments', array([0.1])),
#   ('Application', array([0.1])),
#   ('Implementation', array([0.1])),
#   ('Systems', array([0.1])),
#   ('diversity', array([0.1])),
#   ('Overview', array([0.1])),
#   ('characterization', array([0.1])),
#   ('evaluation', array([0.1])),
#   ('networks', array([0.1])),
#   ('Classification', array([0.1])),
#   ('comparative study', array([0.1])),
#   ('diagnosis', array([0.1])),
#   ('Alzheimer', array([0.1])),
#   ('classification', array([0.1])),
#   ('registration', array([0.1])),
#   ('use', array([0.1])),
#   ('results', array([0.1])),
#   ('visualization', array([0.1])),
#   ('visualization', array([0.1])),
#   ('experiments', array([0.1])),
#   ('Application', array([0.1])),
#   ('Detection', array([0.1])),
#   ('Comparative Study', array([0.1])),
#   ('time', array([0.1])),
#   ('impact', array([0.1]))],
#  1988: [('Detection', array([0.1])),
#   ('Motion', array([0.1])),
#   ('Computation', array([0.9])),
#   ('approach', array([0.2])),
#   ('requirements', array([0.2])),
#   ('case study', array([0.1])),
#   ('data', array([0.2])),
#   ('comparison', array([0.2])),
#   ('tool', array([0.9])),
#   ('use', array([0.3])),
#   ('development', array([0.4])),
#   ('knowledge', array([0.1])),
#   ('Simulation', array([0.2])),
#   ('functions', array([0.2]))],
#  1966: [],
#  1996: [('theory', array([0.1])),
#   ('practice', array([0.1])),
#   ('Performance', array([0.9])),
#   ('image', array([0.2])),
#   ('Development', array([0.2])),
#   ('behavior', array([0.1])),
#   ('internet', array([0.2])),
#   ('Generation', array([0.2])),
#   ('Optimization', array([0.9])),
#   ('Recognition', array([0.3])),
#   ('localization', array([0.4])),
#   ('neural network', array([0.1])),
#   ('Validation', array([0.2])),
#   ('algorithms', array([0.2])),
#   ('mobile robot', array([0.1])),
#   ('real-time systems', array([0.3])),
#   ('Training', array([0.8])),
#   ('synthesis', array([0.1])),
#   ('Detection', array([0.2])),
#   ('human', array([0.3])),
#   ('Implementation', array([0.2])),
#   ('performance evaluation', array([0.1])),
#   ('method', array([0.5])),
#   ('relationship', array([0.3])),
#   ('compression', array([0.2])),
#   ('application', array([0.1])),
#   ('application', array([0.5])),
#   ('method', array([0.2])),
#   ('Design', array([0.1])),
#   ('simulation', array([0.2])),
#   ('Design', array([0.2])),
#   ('analysis', array([0.2])),
#   ('effect', array([0.4])),
#   ('Comparison', array([0.1])),
#   ('algorithms', array([0.1])),
#   ('implications', array([0.1])),
#   ('Collaboration', array([1.])),
#   ('synthesis', array([0.3])),
#   ('relationship', array([0.2])),
#   ('Learning', array([0.2])),
#   ('practice', array([0.2])),
#   ('Issues', array([0.1])),
#   ('resources', array([0.8])),
#   ('Statistical', array([0.1])),
#   ('motion estimation', array([0.2])),
#   ('simulation', array([0.2])),
#   ('overview', array([0.3])),
#   ('application', array([0.3])),
#   ('nonlinear systems', array([0.3]))],
#  1990: [('synthesis', array([0.1])),
#   ('mobile robot', array([0.1])),
#   ('Estimation', array([0.9])),
#   ('software', array([0.2])),
#   ('Control', array([0.2])),
#   ('vision', array([0.1])),
#   ('Estimation', array([0.2])),
#   ('systems', array([0.2])),
#   ('control systems', array([0.9])),
#   ('Design', array([0.3])),
#   ('Computation', array([0.4])),
#   ('Clouds', array([0.1])),
#   ('implications', array([0.2])),
#   ('tool', array([0.2]))],
#  1991: [('approach', array([0.1])),
#   ('Performance', array([0.1])),
#   ('approach', array([0.9])),
#   ('systems', array([0.2])),
#   ('Methods', array([0.2])),
#   ('theory', array([0.1])),
#   ('practice', array([0.2])),
#   ('family', array([0.2])),
#   ('Design', array([0.9])),
#   ('Accurate', array([0.3])),
#   ('history', array([0.4])),
#   ('number', array([0.1])),
#   ('circuits', array([0.2])),
#   ('design', array([0.2])),
#   ('testing', array([0.1])),
#   ('circuits', array([0.3])),
#   ('detection', array([0.8])),
#   ('localization', array([0.1])),
#   ('information systems', array([0.2])),
#   ('Models', array([0.3])),
#   ('parallel', array([0.2])),
#   ('systems', array([0.1])),
#   ('applications', array([0.5])),
#   ('theory', array([0.3])),
#   ('Experiment', array([0.2])),
#   ('Performance analysis', array([0.1])),
#   ('algorithm', array([0.5])),
#   ('representation', array([0.2])),
#   ('models', array([0.1])),
#   ('Algorithms', array([0.2])),
#   ('synthesis', array([0.2])),
#   ('transmission', array([0.2])),
#   ('simulation', array([0.4])),
#   ('robustness', array([0.1]))],
#  2000: [('IEEE', array([0.1])),
#   ('data', array([0.1])),
#   ('XML', array([0.9])),
#   ('real-time systems', array([0.2])),
#   ('analysis', array([0.2])),
#   ('analysis', array([0.1])),
#   ('multicast', array([0.2])),
#   ('Implementation', array([0.2])),
#   ('evaluation', array([0.9])),
#   ('compression', array([0.3])),
#   ('techniques', array([0.4])),
#   ('discovery', array([0.1])),
#   ('measures', array([0.2])),
#   ('Analysis', array([0.2])),
#   ('Design', array([0.1])),
#   ('systems', array([0.3])),
#   ('strategies', array([0.8])),
#   ('linear systems', array([0.1])),
#   ('prediction', array([0.2])),
#   ('Fast', array([0.3])),
#   ('networks', array([0.2])),
#   ('tool', array([0.1])),
#   ('evaluation', array([0.5])),
#   ('use', array([0.3])),
#   ('Issues', array([0.2])),
#   ('future', array([0.1])),
#   ('discovery', array([0.5])),
#   ('Technology', array([0.2])),
#   ('tool', array([0.1])),
#   ('Effects', array([0.2])),
#   ('Analysis', array([0.2])),
#   ('wavelet transform', array([0.2])),
#   ('Performance analysis', array([0.4])),
#   ('novel approach', array([0.1])),
#   ('segmentation', array([0.1])),
#   ('Face Recognition', array([0.1])),
#   ('Development', array([1.])),
#   ('use', array([0.3])),
#   ('Study', array([0.2])),
#   ('Law', array([0.2])),
#   ('framework', array([0.2])),
#   ('performance evaluation', array([0.1])),
#   ('systems', array([0.8])),
#   ('redundant manipulators', array([0.1])),
#   ('environment', array([0.2])),
#   ('case study', array([0.2])),
#   ('Analysis', array([0.3])),
#   ('representation', array([0.3])),
#   ('images', array([0.3])),
#   ('Selection', array([0.5])),
#   ('real-time systems', array([0.1])),
#   ('accurate', array([0.4])),
#   ('Performance', array([0.1])),
#   ('framework', array([0.1])),
#   ('analysis', array([0.1])),
#   ('Requirements', array([0.2])),
#   ('Vision', array([0.3])),
#   ('system', array([0.4])),
#   ('fast', array([0.1])),
#   ('wireless networks', array([0.1])),
#   ('environment', array([0.2])),
#   ('evaluation', array([0.4])),
#   ('algorithm', array([0.2])),
#   ('study', array([0.1])),
#   ('objects', array([0.3])),
#   ('application', array([0.2])),
#   ('algorithm', array([0.2])),
#   ('wireless networks', array([0.1])),
#   ('Method', array([0.1])),
#   ('framework', array([0.2])),
#   ('cellular networks', array([0.2])),
#   ('visualization', array([0.1])),
#   ('new approach', array([0.2])),
#   ('Students', array([0.2])),
#   ('monitoring', array([0.1])),
#   ('Study', array([0.2])),
#   ('knowledge', array([0.1])),
#   ('Visualization', array([0.2])),
#   ('evolution', array([0.2])),
#   ('investigation', array([0.1])),
#   ('applications', array([0.1])),
#   ('embedded systems', array([0.2])),
#   ('mobile robot', array([0.1])),
#   ('recognition', array([0.1])),
#   ('environment', array([0.1])),
#   ('robots', array([0.1])),
#   ('reduction', array([0.1])),
#   ('system', array([0.1])),
#   ('development', array([0.1])),
#   ('XML', array([0.2])),
#   ('use', array([0.2])),
#   ('model', array([0.1])),
#   ('techniques', array([0.1])),
#   ('properties', array([0.3])),
#   ('theory', array([0.2])),
#   ('algorithms', array([0.1])),
#   ('applications', array([0.1])),
#   ('image segmentation', array([0.3])),
#   ('Model', array([0.1])),
#   ('Support', array([0.3])),
#   ('measures', array([0.2])),
#   ('schemes', array([0.2])),
#   ('comparative study', array([0.3])),
#   ('services', array([0.4])),
#   ('overview', array([0.1])),
#   ('information', array([0.4])),
#   ('methodology', array([0.1])),
#   ('Image', array([0.1])),
#   ('impact', array([0.2])),
#   ('diagnosis', array([0.1])),
#   ('testing', array([0.1])),
#   ('implementation', array([0.1])),
#   ('redundant manipulators', array([0.1])),
#   ('applications', array([0.1])),
#   ('maintenance', array([0.4])),
#   ('design', array([0.2])),
#   ('implementation', array([0.1])),
#   ('Taxonomy', array([0.1])),
#   ('objects', array([0.1])),
#   ('schemes', array([0.1]))],
#  2016: [('design', array([0.1])),
#   ('part', array([0.1])),
#   ('embedded systems', array([0.9])),
#   ('application', array([0.2])),
#   ('investigation', array([0.2])),
#   ('Analysis', array([0.1])),
#   ('localization', array([0.2])),
#   ('wireless sensor networks', array([0.2])),
#   ('detection', array([0.9])),
#   ('data mining', array([0.3])),
#   ('Towards', array([0.4])),
#   ('relationship', array([0.1])),
#   ('impact', array([0.2])),
#   ('Uncertainty', array([0.2])),
#   ('Application', array([0.1])),
#   ('Applications', array([0.3])),
#   ('Assessment', array([0.8])),
#   ('methods', array([0.1])),
#   ('approach', array([0.2]))],
#  1968: [('algorithm', array([0.1])),
#   ('algorithm', array([0.1])),
#   ('algorithm', array([0.9]))],
#  1989: [('future', array([0.1])),
#   ('Case Study', array([0.1])),
#   ('application', array([0.9])),
#   ('study', array([0.2])),
#   ('technique', array([0.2])),
#   ('design', array([0.1])),
#   ('implications', array([0.2])),
#   ('techniques', array([0.2])),
#   ('image segmentation', array([0.9])),
#   ('implementation', array([0.3])),
#   ('circuits', array([0.4])),
#   ('speech recognition', array([0.1])),
#   ('throughput', array([0.2])),
#   ('number', array([0.2])),
#   ('classification', array([0.1])),
#   ('Method', array([0.3])),
#   ('Experience', array([0.8])),
#   ('Algorithms', array([0.1])),
#   ('mobile robot', array([0.2])),
#   ('application', array([0.3])),
#   ('design', array([0.2])),
#   ('Stability', array([0.1])),
#   ('Tools', array([0.5]))],
#  1984: [('Tools', array([0.1])),
#   ('Design', array([0.1])),
#   ('Bounds', array([0.9])),
#   ('Computation', array([0.2])),
#   ('robots', array([0.2]))],
#  1981: [('field', array([0.1])),
#   ('speech', array([0.1])),
#   ('theory', array([0.9])),
#   ('applications', array([0.2])),
#   ('Generation', array([0.2])),
#   ('presence', array([0.1])),
#   ('application', array([0.2])),
#   ('vision', array([0.2])),
#   ('reconstruction', array([0.9]))],
#  1986: [('Design', array([0.1])),
#   ('Implementation', array([0.1])),
#   ('strategy', array([0.9])),
#   ('localization', array([0.2])),
#   ('incomplete information', array([0.2]))],
#  1975: [],
#  1985: [('application', array([0.1])),
#   ('estimation', array([0.1])),
#   ('Systems', array([0.9])),
#   ('Performance', array([0.2])),
#   ('systems', array([0.2])),
#   ('systems', array([0.1])),
#   ('problems', array([0.2])),
#   ('presence', array([0.2])),
#   ('faults', array([0.9])),
#   ('System', array([0.3]))],
#  1977: [],
#  1987: [('Applications', array([0.1])),
#   ('presence', array([0.1])),
#   ('decomposition', array([0.9])),
#   ('computation', array([0.2])),
#   ('CPM', array([0.2])),
#   ('Practice', array([0.1])),
#   ('environment', array([0.2])),
#   ('time', array([0.2])),
#   ('Description', array([0.9])),
#   ('verification', array([0.3])),
#   ('protocol', array([0.4]))],
#  2017: [('cloud', array([0.1])), ('survey', array([0.1]))],
#  1974: [('Applications', array([0.1])),
#   ('Classification', array([0.1])),
#   ('Control', array([0.9]))],
#  1965: [('algorithm', array([0.1]))],
#  1964: [('Generation', array([0.1]))],
#  1967: [('Synthesis', array([0.1]))],
#  1962: [],
#  1969: [],
#  1960: [],
#  1982: [('Design', array([0.1])),
#   ('implementation', array([0.1])),
#   ('points', array([0.9])),
#   ('study', array([0.2])),
#   ('images', array([0.2])),
#   ('Application', array([0.1])),
#   ('techniques', array([0.2])),
#   ('nature', array([0.2])),
#   ('heuristics', array([0.9]))],
#  1957: [('Use', array([0.1]))],
#  1978: [('control', array([0.1])), ('real-time systems', array([0.1]))],
#  1973: [],
#  1959: [],
#  1976: [],
#  1961: [('Design', array([0.1]))],
#  1958: [('Investigation', array([0.1]))],
#  1979: [('arrays', array([0.1])),
#   ('Clusters', array([0.1])),
#   ('system', array([0.9]))],
#  1970: [('Synthesis', array([0.1]))],
#  1972: [('Estimation', array([0.1])), ('detection', array([0.1]))],
#  1980: [('graphs', array([0.1])), ('Bounds', array([0.1]))],
#  1971: [('features', array([0.1]))],
#  1954: [('Simulation', array([0.1]))]}
